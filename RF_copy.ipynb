# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn import set_config
set_config(print_changed_only=False)
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('output_merged.csv')
df = df.dropna()
# df = df.drop('ID', axis='columns')
df
# Out:
#       Movie Id                  Movie Name             Director  \
# 0            0                interstellar    Christopher Nolan
# 1            1               thedarkknight    Christopher Nolan
# 2            2  theekenruddhaswasrajasthan    Joydeep Mukherjee
# 3            3  lagaanonceuponatimeinindia   Ashutosh Gowariker
# 4            4                     ramsetu      Abhishek Sharma
# ...        ...                         ...                  ...
# 1889      2124                 dummaarodum          Rohan Sippy
# 1890      2126                       sawii  Darren Lynn Bousman
# 1891      2127           10cloverfieldlane     Dan Trachtenberg
# 1892      2128             jackassthemovie        Jeff Tremaine
# 1893      2130         paranormalactivity3          Henry Joost
#
#                      Lead_Actor              Lead_Actress  Runtime (.)  \
# 0     Matthew David McConaughey  Anne Jacqueline Hathaway          169
# 1                Christian Bale             Anne Hathaway          152
# 2           Anirban Chakrabarti              Naomi Harris          121
# 3                    Aamir Khan               Gracy Singh          224
# 4                  Akshay Kumar      Jacqueline Fernandez          143
# ...                         ...                       ...          ...
# 1889           Jessica Chastain            Joanne Whalley          128
# 1890          Abhishek Bachchan         Shirley Henderson           93
# 1891             Patrick Wilson              Rani Mukerji          103
# 1892            Donnie Wahlberg               Flora Cross           85
# 1893           Johnny Knoxville           Kristen Stewart           83
#
#       IMDb_Rating Language     Animated  Action  ...  Trailer Views  \
# 0             8.7  English  Live Action       1  ...     36314005.0
# 1             9.0  English  Live Action       1  ...    180000000.0
# 2             6.7  Bengali  Live Action       0  ...      1419093.0
# 3             8.1    Hindi  Live Action       0  ...     10460532.0
# 4             5.2    Hindi  Live Action       0  ...     41621819.0
# ...           ...      ...          ...     ...  ...            ...
# 1889          6.2  English  Live Action       0  ...     25004927.0
# 1890          6.6    Hindi  Live Action       0  ...     42061546.0
# 1891          7.2  English  Live Action       0  ...     74493329.0
# 1892          6.6  English  Live Action       1  ...     38980321.0
# 1893          5.8  English  Live Action       0  ...     74738505.0
#
#       Trailer Likes (K)  Follower Count (Lead Actor)  \
# 0                   202                      9000000
# 1                   185                       422000
# 2                    92                        15000
# 3                    86                      2000000
# 4                   796                     67000000
# ...                 ...                          ...
# 1889               4238                        26000
# 1890               3952                      8000000
# 1891               4207                          117
# 1892               3998                     26000000
# 1893               4155                       104000
#
#       Follower Count (Lead Actress)  Follower Count (Director)  \
# 0                          31000000                      97000
# 1                          31000000                      97000
# 2                            467000                       2064
# 3                            146000                        196
# 4                          69000000                     209000
# ...                             ...                        ...
# 1889                         493000                    2000000
# 1890                         387000                        391
# 1891                        6000000                     342000
# 1892                       22000000                      10000
# 1893                       75000000                     148000
#
#       Popularity of Actor Male (POAM)  Popularity of Actress Female (POAF)  \
# 0                                0.60                                 0.29
# 1                                0.32                                 0.39
# 2                                0.50                                 0.23
# 3                                0.13                                 0.23
# 4                                0.33                                 0.46
# ...                               ...                                  ...
# 1889                             0.16                                 0.14
# 1890                             0.42                                 0.37
# 1891                             0.58                                 0.53
# 1892                             0.40                                 0.80
# 1893                             0.75                                 0.40
#
#       Popularity of Director (POD)    CSS      Verdict
# 0                             0.80  0.300  Blockbuster
# 1                             0.80  0.400          Hit
# 2                             0.50  0.238     Superhit
# 3                             0.43  0.350  Blockbuster
# 4                             0.25  0.350         Flop
# ...                            ...    ...          ...
# 1889                          0.33  0.400  Blockbuster
# 1890                          0.48  0.300      Average
# 1891                          0.55  0.450      Average
# 1892                          0.60  0.500      Average
# 1893                          0.56  0.350  Blockbuster
#
# [1894 rows x 58 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le_verdict = LabelEncoder()

# %%
df['Animated'] = le.fit_transform(df['Animated'])
df['Lead_Actor'] = le.fit_transform(df['Lead_Actor'])
df['Lead_Actress'] = le.fit_transform(df['Lead_Actress'])
df['Language'] = le.fit_transform(df['Language'])
df['Director'] = le.fit_transform(df['Director'])
df['Music_Director'] = le.fit_transform(df['Music_Director'])
df['CBFC/MPAA'] = le.fit_transform(df['CBFC/MPAA'])
df['Verdict'] = le_verdict.fit_transform(df['Verdict'])
df
# Out:
#       Movie Id                  Movie Name  Director  Lead_Actor  \
# 0            0                interstellar       144         515
# 1            1               thedarkknight       144         148
# 2            2  theekenruddhaswasrajasthan       471          45
# 3            3  lagaanonceuponatimeinindia        61           3
# 4            4                     ramsetu         2          19
# ...        ...                         ...       ...         ...
# 1889      2124                 dummaarodum       793         367
# 1890      2126                       sawii       174           8
# 1891      2127           10cloverfieldlane       165         590
# 1892      2128             jackassthemovie       387         212
# 1893      2130         paranormalactivity3       332         394
#
#       Lead_Actress  Runtime (.)  IMDb_Rating  Language  Animated  Action  ...  \
# 0               58          169          8.7         1         8       1  ...
# 1               56          152          9.0         1         8       1  ...
# 2              685          121          6.7         0         8       0  ...
# 3              310          224          8.1         2         8       0  ...
# 4              358          143          5.2         2         8       0  ...
# ...            ...          ...          ...       ...       ...     ...  ...
# 1889           426          128          6.2         1         8       0  ...
# 1890           868           93          6.6         2         8       0  ...
# 1891           770          103          7.2         1         8       0  ...
# 1892           281           85          6.6         1         8       1  ...
# 1893           528           83          5.8         1         8       0  ...
#
#       Trailer Views  Trailer Likes (K)  Follower Count (Lead Actor)  \
# 0        36314005.0                202                      9000000
# 1       180000000.0                185                       422000
# 2         1419093.0                 92                        15000
# 3        10460532.0                 86                      2000000
# 4        41621819.0                796                     67000000
# ...             ...                ...                          ...
# 1889     25004927.0               4238                        26000
# 1890     42061546.0               3952                      8000000
# 1891     74493329.0               4207                          117
# 1892     38980321.0               3998                     26000000
# 1893     74738505.0               4155                       104000
#
#       Follower Count (Lead Actress)  Follower Count (Director)  \
# 0                          31000000                      97000
# 1                          31000000                      97000
# 2                            467000                       2064
# 3                            146000                        196
# 4                          69000000                     209000
# ...                             ...                        ...
# 1889                         493000                    2000000
# 1890                         387000                        391
# 1891                        6000000                     342000
# 1892                       22000000                      10000
# 1893                       75000000                     148000
#
#       Popularity of Actor Male (POAM)  Popularity of Actress Female (POAF)  \
# 0                                0.60                                 0.29
# 1                                0.32                                 0.39
# 2                                0.50                                 0.23
# 3                                0.13                                 0.23
# 4                                0.33                                 0.46
# ...                               ...                                  ...
# 1889                             0.16                                 0.14
# 1890                             0.42                                 0.37
# 1891                             0.58                                 0.53
# 1892                             0.40                                 0.80
# 1893                             0.75                                 0.40
#
#       Popularity of Director (POD)    CSS  Verdict
# 0                             0.80  0.300        1
# 1                             0.80  0.400        4
# 2                             0.50  0.238        7
# 3                             0.43  0.350        1
# 4                             0.25  0.350        3
# ...                            ...    ...      ...
# 1889                          0.33  0.400        1
# 1890                          0.48  0.300        0
# 1891                          0.55  0.450        0
# 1892                          0.60  0.500        0
# 1893                          0.56  0.350        1
#
# [1894 rows x 58 columns]

# %%
max_encoded_value = max(le_verdict.classes_)
print(le_verdict.classes_)
max_encoded_value
# Out:
# ['Average' 'Blockbuster' 'Disaster' 'Flop' 'Hit' 'Outstanding'
#  'Successful' 'Superhit']
# 'Superhit'

# %%
le_name_mapping = dict(zip(le_verdict.classes_, le_verdict.transform(le_verdict.classes_)))
le_name_mapping
# Out:
# {'Average': 0,
#  'Blockbuster': 1,
#  'Disaster': 2,
#  'Flop': 3,
#  'Hit': 4,
#  'Outstanding': 5,
#  'Successful': 6,
#  'Superhit': 7}

# %%
X = df.drop('Verdict', axis='columns')
X = df.drop('Movie Name', axis='columns')
# X['CSS'] = X['CSS'].fillna(X['CSS'].median())
# X['No. of Screens'] = X['No. of Screens'].fillna(X['No. of Screens'].median())
X['CSS'] *= 2

# %%
nan_columns = X.columns[X.isna().any()].tolist()
if nan_columns:
    print("Columns with NaN values:", nan_columns)
else:
    print("No NaN values found in any column.")
# Out:
# No NaN values found in any column.

# %%
y = df['Verdict']
y.dropna()
# Out:
# 0       1
# 1       4
# 2       7
# 3       1
# 4       3
#        ..
# 1889    1
# 1890    0
# 1891    0
# 1892    0
# 1893    1
# Name: Verdict, Length: 1894, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)

len(X_test)
# Out:
# 474

# %%
# from sklearn.model_selection import GridSearchCV
# param_grid = {
#     'n_estimators': [50, 100, 200],
#     'max_depth': [None, 10, 20],
#     'min_samples_split': [2, 5, 10],
#     'min_samples_leaf': [1, 2, 4]
# }

# # Perform grid search for hyperparameter tuning
# grid_search = GridSearchCV(RandomForestClassifier(), param_grid, cv=5)
# grid_search.fit(X_train_scaled, y_train)

# # Get the best model
# model = grid_search.best_estimator_

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.9535864978902954

# %%
y_predicted = model.predict(X_test)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predicted)

# %%
y_predicted_verdict_all = model.predict(X)
df['Predicted Verdict by RF'] = le_verdict.inverse_transform(y_predicted_verdict_all)
df['Verdict'] = le_verdict.inverse_transform(y)
df.to_csv('output_with_predictionsRF_75-25.csv', index=False)

# %%
# %matplotlib inline
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
from sklearn.metrics import accuracy_score
ac = accuracy_score(y_test, y_predicted)
# round(ac, 3)
print(ac)
# Out:
# 0.9535864978902954

# %%
from sklearn.metrics import f1_score
f1 = f1_score(y_test, y_predicted, average=None)
f1
# Out:
# array([0.94871795, 0.94222222, 0.        , 0.89320388, 0.98816568,
#        0.        , 0.97461929])

# %%
from sklearn.metrics import recall_score
rs = recall_score(y_test, y_predicted, average=None)
rs
# Out:
# array([0.925     , 0.96363636, 0.        , 0.88461538, 1.        ,
#        0.        , 0.97959184])

# %%
from sklearn.metrics import precision_score
ps = precision_score(y_test, y_predicted, average=None)
ps
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# array([0.97368421, 0.92173913, 0.        , 0.90196078, 0.97660819,
#        0.        , 0.96969697])

# %%
print("Confusion Matrix:\n", cm)
print("\nF1 Score:", f1)
print("\nRecall Score", rs)
print("\nPrecision Score:", ps)
# Out:
# Confusion Matrix:
#  [[ 37   2   0   1   0   0   0]
#  [  1 106   0   3   0   0   0]
#  [  0   3   0   1   0   0   0]
#  [  0   4   0  46   2   0   0]
#  [  0   0   0   0 167   0   0]
#  [  0   0   0   0   0   0   3]
#  [  0   0   0   0   2   0  96]]
#
# F1 Score: [0.94871795 0.94222222 0.         0.89320388 0.98816568 0.
#  0.97461929]
#
# Recall Score [0.925      0.96363636 0.         0.88461538 1.         0.
#  0.97959184]
#
# Precision Score: [0.97368421 0.92173913 0.         0.90196078 0.97660819 0.
#  0.96969697]

# %%
weighted_f1 = f1_score(y_test, y_predicted, average='weighted')
weighted_recall = recall_score(y_test, y_predicted, average='weighted')
weighted_precision = precision_score(y_test, y_predicted, average='weighted')
weighted_roc_auc = roc_auc_score(y_test_binarized, y_pred_prob, average='weighted', multi_class='ovr')

print("Weighted ROC AUC Score:", weighted_roc_auc)
print("Weighted F1 Score:", weighted_f1)
print("Weighted Recall Score:", weighted_recall)
print("Weighted Precision Score:", weighted_precision)
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 4
#       2 weighted_recall = recall_score(y_test, y_predicted, average='weighted')
#       3 weighted_precision = precision_score(y_test, y_predicted, average='weighted')
# ----> 4 weighted_roc_auc = roc_auc_score(y_test_binarized, y_pred_prob, average='weighted', multi_class='ovr')
#       6 print("Weighted ROC AUC Score:", weighted_roc_auc)
#       7 print("Weighted F1 Score:", weighted_f1)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_ranking.py:648, in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     640     return _average_binary_score(
#     641         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     642         y_true,
#    (...)
#     645         sample_weight=sample_weight,
#     646     )
#     647 else:  # multilabel-indicator
# --> 648     return _average_binary_score(
#     649         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     650         y_true,
#     651         y_score,
#     652         average,
#     653         sample_weight=sample_weight,
#     654     )
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_base.py:116, in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#     114 score = np.zeros((n_classes,))
#     115 for c in range(n_classes):
# --> 116     y_true_c = y_true.take([c], axis=not_average_axis).ravel()
#     117     y_score_c = y_score.take([c], axis=not_average_axis).ravel()
#     118     score[c] = binary_metric(y_true_c, y_score_c, sample_weight=score_weight)
#
# IndexError: index 7 is out of bounds for axis 1 with size 7

# %%
# Get feature importances
feature_importances = model.feature_importances_

# Display feature importances
feature_importance_df = pd.DataFrame({'Feature': X_train.columns, 'Importance': feature_importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
print(feature_importance_df)
feature_importance_df.to_csv('importance.csv')
# Out:
#                                 Feature  Importance
# 56                              Verdict    0.406026
# 0                              Movie Id    0.039995
# 44                  Overseas Collection    0.036390
# 39                BO Collection (Total)    0.036084
# 47                        Trailer Views    0.033836
# 48                    Trailer Likes (K)    0.028918
# 40                             1st Week    0.025166
# 42                             3rd Week    0.023667
# 45                               Budget    0.022480
# 43                             4th Week    0.022378
# 41                             2nd Week    0.022224
# 49          Follower Count (Lead Actor)    0.019933
# 2                            Lead_Actor    0.019241
# 5                           IMDb_Rating    0.018927
# 3                          Lead_Actress    0.018727
# 4                           Runtime (.)    0.018534
# 1                              Director    0.017723
# 50        Follower Count (Lead Actress)    0.017535
# 36                         Music_Rating    0.017458
# 51            Follower Count (Director)    0.017409
# 37                       Music_Director    0.017080
# 46                       No. of Screens    0.015504
# 54         Popularity of Director (POD)    0.014748
# 52      Popularity of Actor Male (POAM)    0.014691
# 53  Popularity of Actress Female (POAF)    0.014326
# 55                                  CSS    0.012075
# 38                            CBFC/MPAA    0.007666
# 16                                Drama    0.003554
# 8                                Action    0.003397
# 14                                Crime    0.003037
# 10                            Adventure    0.002906
# 13                               Comedy    0.002784
# 28                              Romance    0.002639
# 18                              Fantasy    0.002231
# 33                             Thriller    0.002150
# 7                              Animated    0.002110
# 29                               Sci-Fi    0.001876
# 22                               Horror    0.001856
# 12                            Biography    0.001839
# 17                               Family    0.001810
# 25                              Mystery    0.001729
# 6                              Language    0.001474
# 11                            Animation    0.001276
# 15                          Documentary    0.001012
# 23                                Music    0.000827
# 21                              History    0.000752
# 34                                  War    0.000708
# 31                                Sport    0.000677
# 35                              Western    0.000362
# 24                              Musical    0.000131
# 30                                Short    0.000118
# 32                            Talk-Show    0.000000
# 20                            Game-Show    0.000000
# 26                                 News    0.000000
# 9                                 Adult    0.000000
# 27                           Reality-TV    0.000000
# 19                            Film-Noir    0.000000
